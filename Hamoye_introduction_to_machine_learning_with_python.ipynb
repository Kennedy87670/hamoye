# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv' , encoding='latin-1')

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df.tail()
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit  Y2014  Y2015  \
# 60938                                    Food      1000 tonnes  42.00  46.00
# 60939     Food supply quantity (kg/capita/yr)               kg   3.06   3.33
# 60940           Food supply (kcal/capita/day)  kcal/capita/day   3.00   4.00
# 60941  Protein supply quantity (g/capita/day)     g/capita/day   0.10   0.11
# 60942      Fat supply quantity (g/capita/day)     g/capita/day   0.04   0.05
#
#        Y2016  Y2017  Y2018
# 60938  33.00  19.00  16.00
# 60939   2.35   1.33   1.08
# ...

# %%
# 1) Which of these python data structures is unorderly?
## answer set

# %%
# 2) 
#Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’. 
#Which of these Areas had the highest sum in 2017?

df.groupby(['Y2017'])['Area'].sum()
# answer: Nigeria
# Out:
# Y2017
# -1582.0                       EgyptEgypt
# -1200.0                       Mozambique
# -1159.0                       Mozambique
# -865.0       United Republic of Tanzania
# -860.0       United Republic of Tanzania
#                         ...
#  96443.0                           Egypt
#  106400.0                       Ethiopia
#  112625.0                        Nigeria
#  117702.0                        Nigeria
#  190873.0                        Nigeria
# Name: Area, Length: 4537, dtype: object

# %%
# 3) What is the total number and percentage of missing data in 2014 to 3 decimal places?
gh=df['Y2014'].isna().sum()
gh
# answer E
# Out:
# 1589

# %%
# 4) Which year had the least correlation with ‘Element Code’?
df.corr().sum()
#answer 2017
# Out:
# Area Code       1.022186
# Item Code       1.075654
# Element Code    1.095431
# Y2014           5.033173
# Y2015           5.016861
# Y2016           5.026162
# Y2017           5.024920
# Y2018           5.025198
# dtype: float64

# %%
# 5) Which of the following dataframe methods can be used to access elements across rows and columns?
# answer  df.iloc[ : ]

# %%
# 6) What is the mean and standard deviation across the whole dataset for the year 2017 to 2 decimal places?
df.describe()
# answer D 140.92 and 1671.86
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
# 7) A pandas Dataframe with dimensions (100,3) has how many features and observations?
 # ans: A 100 rows and 3 observations.

# %%
# 8) Perform a groupby operation on ‘Element’.  What year has the highest sum of Stock Variation?
df.groupby(['Element']).describe()
# Out:
#                                        Area Code                              \
#                                            count        mean        std  min
# Element
# Domestic supply quantity                  5295.0  133.898584  72.429582  4.0
# Export Quantity                           4403.0  136.250284  72.474261  4.0
# Fat supply quantity (g/capita/day)        5023.0  134.391798  72.408886  4.0
# Feed                                      1319.0  133.640637  71.452934  4.0
# Food                                      4941.0  134.243068  72.466059  4.0
# Food supply (kcal/capita/day)             5014.0  134.434982  72.358700  4.0
# Food supply quantity (kg/capita/yr)       4905.0  134.239755  72.455564  4.0
# Import Quantity                           5139.0  133.912045  72.365119  4.0
# Losses                                    2009.0  136.561971  72.785591  4.0
# Other uses (non-food)                     1732.0  136.001155  73.106619  4.0
# ...

# %%
# 9) 
#If you have the following list

# lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

# col = [‘Age’,’Nationality’,’Overall’]

# How do you create a pandas DataFrame using this list, to look like the table below?

#answer C pd.Dataframe(lst, columns = col, index = [1,2,3])

# %%
# 10) How would you check for the number of rows and columns in a pandas DataFrame named df?
# ANS: c df.shape

# %%
# 11) Given the following python code, what would the output of the code give?

# my_tuppy = (1,2,5,8)

# my_tuppy[2] = 6

# Ans: D type error

# %%
# 12) Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the 7th lowest sum in 2017?
df.groupby(['Y2017','Area'])['Area'].sum()
# Out:
# Y2017      Area
# -1582.0    Egypt                                           EgyptEgypt
# -1200.0    Mozambique                                      Mozambique
# -1159.0    Mozambique                                      Mozambique
# -865.0     United Republic of Tanzania    United Republic of Tanzania
# -860.0     United Republic of Tanzania    United Republic of Tanzania
#                                                      ...
#  96443.0   Egypt                                                Egypt
#  106400.0  Ethiopia                                          Ethiopia
#  112625.0  Nigeria                                            Nigeria
#  117702.0  Nigeria                                            Nigeria
#  190873.0  Nigeria                                            Nigeria
# Name: Area, Length: 14773, dtype: object

# %%
# 13) 
# What is the total number of unique countries in the dataset?
for column in df.columns:
    print(column,":::::: ",df[column].unique())
    
# ans: A 49
# Out:
# Area Code ::::::  [  4   7  53  20 233  35  32  37  39  45  46 107  72  59 209 238  62  74
#   75  81  90 175 114 122 123 129 130 133 136 137 143 144 147 158 159 184
#  193 195 196 197 202 276 206 217 222 226 215 251 181]
# Area ::::::  ['Algeria' 'Angola' 'Benin' 'Botswana' 'Burkina Faso' 'Cabo Verde'
#  'Cameroon' 'Central African Republic' 'Chad' 'Comoros' 'Congo'
#  "Côte d'Ivoire" 'Djibouti' 'Egypt' 'Eswatini' 'Ethiopia' 'Ethiopia PDR'
#  'Gabon' 'Gambia' 'Ghana' 'Guinea' 'Guinea-Bissau' 'Kenya' 'Lesotho'
#  'Liberia' 'Madagascar' 'Malawi' 'Mali' 'Mauritania' 'Mauritius' 'Morocco'
#  'Mozambique' 'Namibia' 'Niger' 'Nigeria' 'Rwanda' 'Sao Tome and Principe'
#  'Senegal' 'Seychelles' 'Sierra Leone' 'South Africa' 'Sudan'
#  'Sudan (former)' 'Togo' 'Tunisia' 'Uganda' 'United Republic of Tanzania'
#  'Zambia' 'Zimbabwe']
# Item Code ::::::  [2501 2901 2903 2941 2905 2511 2805 2513 2514 2515 2516 2517 2518 2520
#  2907 2532 2531 2533 2535 2534 2908 2536 2537 2909 2542 2543 2745 2911
# ...

# %%
# 14) 
# Perform a groupby operation on ‘Element’.  What is the total number of the sum of Processing in 2017?
df.groupby(['Element'])['Y2017'].sum()
# ans: E 292836.00
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %%
# 15) 
# Which of the following is a python inbuilt module?
# ANS: B math

# %%
# 16) What would be the output for?

S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'

# %%
# 17) Answer the following questions based on the African food production dataset provided by the FAO website already provided

# What is the total sum of Wine produced in 2015 and 2018 respectively?

# Hint:

# Perform a groupby sum aggregation on ‘Item’
df.groupby(['Item'])['Y2015', 'Y2018'].sum()
# ans 4251.81 and 4039.32
# Out:
# C:\Users\JOHNKENNEDY\AppData\Local\Temp\ipykernel_17060\2612083911.py:8: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Item'])['Y2015', 'Y2018'].sum()
#                          Y2015      Y2018
# Item
# Alcohol, Non-Food      2180.00    2293.00
# Alcoholic Beverages   98783.72   97847.27
# Animal Products       11811.73   11578.61
# Animal fats          200675.72  269648.27
# Apples and products   10559.15    9640.51
# ...                        ...        ...
# Vegetables, Other    158104.08  163987.21
# Vegetal Products     107064.17  107775.39
# Wheat and products   234710.51  242645.19
# Wine                   4251.81    4039.32
# Yams                 203151.78  221272.09
#
# [119 rows x 2 columns]

# %%
# 18) What is the total Protein supply quantity in Madagascar in 2015?
df.groupby(['Element'])['Y2015', 'Area'].sum()
# df.groupby([])['Y2017'].sum()
# Out:
# C:\Users\JOHNKENNEDY\AppData\Local\Temp\ipykernel_17060\1260714693.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Element'])['Y2015', 'Area'].sum()
#                                              Y2015
# Element
# Domestic supply quantity                2021493.55
# Export Quantity                          157614.47
# Fat supply quantity (g/capita/day)        10235.74
# Feed                                     225050.22
# Food                                    1232361.10
# Food supply (kcal/capita/day)            453383.00
# Food supply quantity (kg/capita/yr)       49345.13
# Import Quantity                          267018.46
# Losses                                   155439.00
# Other uses (non-food)                     66254.41
# Processing                               287929.00
# Production                              1947019.39
# ...

# %%
# 19) 
# Given the following numpy array 

array  = ([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])

# How would you select  the elements in bold and italics from the array?
#array[ : 2, 1 : ]

# %%
# 20) Consider the following list of tuples:

y = [(2, 4), (7, 8), (1, 5, 9)]

# How would you assign element 8 from the list to a variable x?
# ans: x = y[1][-1]
